# %% [markdown]
# # Rofous Dev
# This file is where you can test and develop functionalities for the rofous project

# %%
import numpy as np
import Aerial_Device
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %% [markdown]
# ### PID example

# %%
rofous = Aerial_Device.Aerial_Device(memory_length=10000)
artist = Aerial_Device.Renderer(rofous)
rofous.reset()
target = (0,0,4,0,0,np.radians(90))

for i in range(10000):
    rofous.adjust_throttles(target=target)
    rofous.update_odometry()
    if np.abs(np.sum(rofous.id.path['accelerations'][-7:])) < 1e-4:
        break
        
print(target - rofous.poseActual)   
artist.render()
# Out:
# [ 0.          0.         -0.13446729  0.          0.          0.20006262]

# %%
rofous = Aerial_Device.Aerial_Device(memory_length=10000)
artist = Aerial_Device.Renderer(rofous)
target = [0,0,10,0,0,0]

sp = [np.linalg.norm(target)]
pv = []
op = []
a = 1e-5
scores = []
gains = []
rofous.control.gains = [0.5, 0, 0]

for i in range(10):
    rofous.reset()
    p_ctr = 0
    peak = 0
    max_o = 0
    for j in range(10000):
        rofous.adjust_throttles(target=target)
        rofous.update_odometry()
        #pv.append(np.linalg.norm(rofous.poseActual))
        #op.append(np.linalg.norm(rofous.throttle))
        if np.sign(np.sum(rofous.id.path['velocities'][-1])) != np.sign(np.sum(rofous.id.path['velocities'][-2])):
            if np.linalg.norm(rofous.poseActual - target) > max_o and j != 0:
                max_o = np.linalg.norm(rofous.poseActual - target)
                peak = j
            p_ctr += 1
        if np.abs(np.sum(rofous.id.path['accelerations'][-5:])) < 1e-3:
            break
    print(p_ctr, max_o, peak)
    scores.append(p_ctr * 1000 / (max_o + peak))
    gains.append(rofous.control.gains)
    rofous.control.gains += np.array([-max_o*peak*a, max_o*peak*a, peak*a/5])
        
print(rofous.control.gains)  
gains = np.array(gains)
x = np.arange(0,len(scores))
"""
plt.plot(x, ((pv-np.mean(pv)) / np.std(pv)) + sp[0], 'r', label='Effect')
plt.plot(x, ((op-np.mean(op)) / np.std(op)) + sp[0], 'g', label='Control')
plt.plot(x, sp*len(pv), 'b', label='Target')
plt.legend()
plt.show()"""

plt.plot(x, gains[:,0], 'g')
plt.plot(x, gains[:,1], 'b')
plt.plot(x, gains[:,2], 'c')
plt.plot(x, scores, 'r')
plt.show()
   
artist.render()
# Out:
# 5 1632.308867522419 8373
# 6 1632.308867522419 8373
# 7 1632.308867522419 8373
# 8 1632.308867522419 8373
# 9 1632.308867522419 8373
# 10 1632.308867522419 8373
# 11 1632.308867522419 8373
# 12 1632.308867522419 8373
# 13 1632.308867522419 8373
# 14 1632.308867522419 8373
# [-1.36623221e+03  1.36673221e+03  1.67460000e-01]
